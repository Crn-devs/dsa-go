// %%
import (
	"fmt"

	arr "github.com/Crn-devs/dsa-go/array"
)

// %% [markdown]
// # Reverse a string using arrays

// %%
func ReverseStringArray(s string) string {

	// first check input is correct
	if len(s) <= 0 {
		fmt.Println("incorrect length: length should be greater than 0")
	}

	// create an array to store reversed string
	reversed := make([]string, len(s))

	// run reverse loop
	for i := len(s) - 1; i >= 0; i-- {
		// add revered items to the array
		reversed[len(s)-1-i] = string(s[i])
	}

	// implement toString method instead
	return strings.Join(reversed, "")
}

%%
fmt.Println(ReverseStringArray("Hello"))
// Out:
// olleH
